# %% [markdown]
# 음료수를 구매 할 수 있는 자판기 입니다. 음료수 종류 및 개당 금액
#
# - 콜라 : 500
# - 사이다 : 450
# - 맥콜 : 300

# %%
선택한음료 = input("콜라, 사이다, 맥콜 중 하나를 주문하세요.")
'문제1) 아래의 조건문에서 해다당 음료수를 선택했을 경우 금액을 알려주시고 수량을 받는 입력창을 띄우세요.'
'문제2) 선택한 음료와 수량의 총 합을 출력해 주세요. 예) 콜라 3개 금액은 1500원 입니다.'
'문제3) 사용자에서 금액을 받고 알맞은 결과를 출력해 주세요. 예) 2000원을 받고 500원 거스름돈을 받으세요.'
